# %%
# !find ~ -name "*ATROI*"
# Out:
# find: ‘/home/ljp238/.dbus’: Permission denied
# find: ‘/home/ljp238/snap/code/217’: Permission denied
# /home/ljp238/.local/share/QGIS/QGIS3/profiles/default/gdal_pam/000087__media_ljp238_12TBWolf_BRCHIEVE_ATROI_tif_N10E105_ID0_mosaik_DevOps_N10E105_tdem_dem_egm_v_3_gap_gF3_0_100_inv_dist_LCL_N10E105_gf3_lcl_rd5dw1pw2_0_mod2.sdat.aux.xml
# /home/ljp238/.local/share/QGIS/QGIS3/profiles/default/gdal_pam/000086__media_ljp238_12TBWolf_BRCHIEVE_ATROI_tif_N10E105_ID0_mosaik_DevOps_N10E105_tdem_dem_egm_v_3_gap_gF3_0_100_inv_dist_LCL_N10E105_gf3_lcl_rd5dw0_mod1.sdat.aux.xml
# ^C

# %%
#!locate ATROI # better than find, but needs updatedb to be run first
# !locate *clip*roi
# Out:
# /etc/xdg/autostart/xfce4-clipman-plugin-autostart.desktop
# /etc/xdg/xfce4/panel/xfce4-clipman-actions.xml
# /home/ljp238/.cache/uv/archive-v0/DT5Q2gMPW4EQpRwB_CLhd/shapely/tests/legacy/test_clip_by_rect.py
# /home/ljp238/.cache/uv/archive-v0/ETlOdrZJTUu4qIKaQSJUI/IPython/lib/clipboard.py
# /home/ljp238/.cache/uv/archive-v0/HvYkyGtnBGcnXBw-k_zWK/geopandas/tools/clip.py
# /home/ljp238/.cache/uv/archive-v0/HvYkyGtnBGcnXBw-k_zWK/geopandas/tools/tests/test_clip.py
# /home/ljp238/.cache/uv/archive-v0/J9JUAKdIG7QfA90MN-z9j/geopandas/tools/clip.py
# /home/ljp238/.cache/uv/archive-v0/J9JUAKdIG7QfA90MN-z9j/geopandas/tools/tests/test_clip.py
# /home/ljp238/.cache/uv/archive-v0/M1sxswRSczr_GbqmlctkR/shapely/tests/legacy/test_clip_by_rect.py
# /home/ljp238/.cache/uv/archive-v0/Mpd4AYMiDtUFgmKIbU1kU/pandas/io/clipboard
# /home/ljp238/.cache/uv/archive-v0/Mpd4AYMiDtUFgmKIbU1kU/pandas/io/clipboards.py
# /home/ljp238/.cache/uv/archive-v0/Mpd4AYMiDtUFgmKIbU1kU/pandas/io/clipboard/__init__.py
# ...

# %%
#!find ~/Downloads -name "*ch*"

# %%
# !find ~/Downloads -name "*facebook*"

# %%
# !find ~/Downloads -name "*facebook*"

# %%
# !find ~/Documents -name "*fb*"
# Out:
# /home/ljp238/Documents/zprojx/Psaga/Psaga/.git/objects/55/04e5499951019e36881ba7e7b6159fb1ba4b36
# /home/ljp238/Documents/zprojx/Psaga/Psaga/.git/objects/c7/0b3a233df2599288b4275003e9b50a427fb393
# /home/ljp238/Documents/zprojx/Psaga/Psaga/.git/objects/d6/75c9020c00cdfcb00cabfb6365e2ff4ef1e182
# /home/ljp238/Documents/zprojx/Psaga/Psaga/.git/objects/0b/f38ecd91e4bdfb1da09c01b9480ecbf95ffb0f
# /home/ljp238/Documents/zprojx/Psaga/Psaga/.git/objects/99/391b20b9462ab843fbbab7479b3a99a6ecc053
# /home/ljp238/Documents/zprojx/Psaga/Psaga/.git/objects/f2/fb153906e612fcb0769afd48a93a5203df706a
# /home/ljp238/Documents/zprojx/Psaga/Psaga/.git/objects/38/0ef95992510e947e8815226e53d2e1de2fb090
# /home/ljp238/Documents/zprojx/Psaga/Psaga/.git/objects/f0/f647aa51ff145cb94191bd9cafb311ddd0dc19
# /home/ljp238/Documents/zprojx/Psaga/Psaga/.git/objects/fc/fb66cde1c9f054ac5a68911a0993c5742d444b
# ...
