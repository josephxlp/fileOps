# %%
import os

# %%
rem = "/home/ljp238/OneDrive/music/Intercessor/IntercessorMy"
loc = 'IntercessorMy'
os.makedirs(loc, exist_ok=True)

# %%
from uRclone import download_dir

# %%
#download_dir(rem,loc)

# %%
# can you use rclone to also copy file sfrom one drive to another 
# any fast tools todo it in linux?
